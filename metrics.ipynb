# %%
from config import parse_config

config = parse_config("./config/train.yaml")
config
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from config import parse_config
# ----> 3 config = parse_config("./confg/train.yaml")
#       4 config
#
# File ~/hstasnet/config/parse.py:8, in parse_config(config_file)
#       7 def parse_config(config_file):
# ----> 8     with open(config_file, 'r') as f:
#       9         config = yaml.safe_load(f)
#      10     return config
#
# FileNotFoundError: [Errno 2] No such file or directory: './confg/train.yaml'
